# %% [markdown]
# # ETL_EDA
# This file records the process of acquiring raw data, traforming them, and loading them into a MongoDB. The data are store (almost) in their raw form.

# %% [markdown]
# ## 1. Raw Data from BPA
# The [dataset](https://transmission.bpa.gov/business/operations/Wind/baltwg.txt) is a continuously updated txt file in csv format. It contains the energy producation and load in the last 5 days. There will be some blank lines at the end for today. It can be retrieved simply by making `requests` without parameters. For more complicated API call, you may need to add query parameters.

# %%
import requests

url = "https://transmission.bpa.gov/business/operations/Wind/baltwg.txt"
req = requests.get(url, timeout=0.5)
req.raise_for_status()
text = req.text
print(text[:1000])
print('...')
print(text[-500:])
# Out:
# BPA Balancing Authority Load & Total Wind Generation
# at 5-minute intervals, last 7 days
# Dates: 30Nov2019 - 07Dec2019 (last updated 6Dec2019 13:30:34) Pacific Time
# Based on 5-min MW readings from the BPA SCADA system for points 45583, 79687, 79682, 164377, 70681
#
# This represents loads and resources in BPA's Balancing Authority (BA) including some that are not BPA's.
# It does not include BPA loads served by transfer, scheduled out of region,
# or scheduled to customers with their own BAs such as Seattle and Tacoma
#
# BPA/Technical Operations (TOT-OpInfo@bpa.gov)
#
# Date/Time       	Load	Wind	Hydro	Fossil/Biomass	Nuclear
# 11/30/2019 00:00	7143	35	6844	506	1168
# 11/30/2019 00:05	7146	35	6832	508	1170
# 11/30/2019 00:10	7122	31	6842	510	1167
# 11/30/2019 00:15	7138	29	6714	505	1170
# 11/30/2019 00:20	7097	27	6739	506	1168
# 11/30/2019 00:25	7086	26	6721	506	1169
# 11/30/2019 00:30	7119	26	6745	508	1167
# 11/30/2019 00:35	7117	23	6763	509	1167
# 11/30/2019 00:40	7128	19	6688	509	1169
# 11/30/201
# ...
# 2019 22:10
# 12/06/2019 22:15
# 12/06/2019 22:20
# 12/06/2019 22:25
# 12/06/2019 22:30
# 12/06/2019 22:35
# 12/06/2019 22:40
# 12/06/2019 22:45
# 12/06/2019 22:50
# 12/06/2019 22:55
# 12/06/2019 23:00
# 12/06/2019 23:05
# 12/06/2019 23:10
# 12/06/2019 23:15
# 12/06/2019 23:20
# 12/06/2019 23:25
# 12/06/2019 23:30
# 12/06/2019 23:35
# 12/06/2019 23:40
# 12/06/2019 23:45
# 12/06/2019 23:50
# 12/06/2019 23:55

# %%
import charts
import datetime
today = datetime.datetime.today() #2019-12-05#
today= today.strftime("%Y-%m-%d")
lastweek = datetime.datetime.today() - datetime.timedelta(days = 1)
lastweek = lastweek.strftime("%Y-%m-%d")
chart = charts.get_charts(lastweek, today,region='nl')
chart.head()
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# <_io.StringIO object at 0x120a56318>
#    Position           Track Name          Artist  Streams  \
# 0         1         Dance Monkey     Tones and I   282587
# 1         2         Pa Olvidarte   Emma Heesters   230923
# 2         3             Memories        Maroon 5   211134
# 3         4              ROXANNE  Arizona Zervas   199803
# 4         5  everything i wanted   Billie Eilish   171956
#
#                                                  URL       date
# 0  https://open.spotify.com/track/1rgnBhdG2JDFTbY... 2019-12-05
# 1  https://open.spotify.com/track/1RO8Q3w2Jkir8cv... 2019-12-05
# 2  https://open.spotify.com/track/2b8fOow8UzyDFAE... 2019-12-05
# 3  https://open.spotify.com/track/696DnlkuDOXcMAn... 2019-12-05
# 4  https://open.spotify.com/track/3ZCTVFBt2Brf31R... 2019-12-05

# %% [markdown]
# ## 2. Raw Data to Documents/Dicts
# Using pandas, it is simple to parse a in-memory string. The first few lines of description need to be skipped. Datetime conversion is made and blank lines are dropped. Now the data can be easily converted to a list of dicts which is what we want for the MongoDB.

# %%
import pandas
from io import StringIO

df = pandas.read_csv(StringIO(text), skiprows=11, delimiter='\t')
df.columns = df.columns.str.strip()             # remove space in columns name
df['Datetime'] = pandas.to_datetime(df['Date/Time'])
df.drop(columns=['Date/Time'], axis=1, inplace=True)
df.dropna(inplace=True)  
df.head()
# Out:
#      Load  Wind   Hydro  Fossil/Biomass  Nuclear            Datetime
# 0  7143.0  35.0  6844.0           506.0   1168.0 2019-11-30 00:00:00
# 1  7146.0  35.0  6832.0           508.0   1170.0 2019-11-30 00:05:00
# 2  7122.0  31.0  6842.0           510.0   1167.0 2019-11-30 00:10:00
# 3  7138.0  29.0  6714.0           505.0   1170.0 2019-11-30 00:15:00
# 4  7097.0  27.0  6739.0           506.0   1168.0 2019-11-30 00:20:00

# %%
import pandas
import spotipy
import spotipy.util as util
import sys
# define authentication
username = 'zhiyanwang27'
scope = 'user-read-private'

CLIENT_ID = '1d35e049282a4f198bd09ff07e105784'
CLIENT_SECRET = '54850e7841cb47c5bc6c8970457dee89'

# playlist_id = '6watTtiqGlxPj2cxy6Sk8U'

token = util.prompt_for_user_token(username, 
                                   scope,
                                   client_id=CLIENT_ID,
                                   client_secret=CLIENT_SECRET,
                                   redirect_uri='http://localhost/8000/')

sp = spotipy.Spotify(auth=token)

# %%
df = chart
df['date'] = pandas.to_datetime(df['date'])
df['ID'] = 'default value'
df['genre'] = 'default value'
df['follwers'] = 'default value'
for i in range(df.shape[0]):
    track_id = df.iloc[i,4][31:]
    df.iloc[i,6] = track_id
    artist_id = sp.track(track_id)['artists'][0]['id']
    if len(sp.artist(artist_id)['genres']) > 0:
        gr = sp.artist(artist_id)['genres'][0]
    else:
        gr = 'None'
    fl = sp.artist(artist_id)['followers']['total']
    df.iloc[i,7] = gr
    df.iloc[i,8] = fl
df
# Out:
#      Position                                         Track Name  \
# 0           1                                       Dance Monkey
# 1           2                                       Pa Olvidarte
# 2           3                                           Memories
# 3           4                                            ROXANNE
# 4           5                                everything i wanted
# 5           6                                            Circles
# 6           7                                             Reünie
# 7           8                                  Someone You Loved
# 8           9                                    Don't Start Now
# 9          10                                        Lippenstift
# 10         11                                            Ride It
# 11         12                                      Hoe Het Danst
# 12         13                    All I Want for Christmas Is You
# 13         14                                Lose You To Love Me
# 14         15                                        Ze Kent Mij
# 15         16                                            DomDoen
# 16         17                                               Liar
# 17         18                                         Blauwe Dag
# 18         19                                           Señorita
# 19         20                    Beautiful People (feat. Khalid)
# 20         21                                       Lose Control
# 21         22  South of the Border (feat. Camila Cabello & Ca...
# 22         23                                     Last Christmas
# 23         24                                       Voor Je Deur
# 24         25                           Post Malone (feat. RANI)
# 25         26                                  How Do You Sleep?
# 26         27                                            My Bébé
# 27         28                  10,000 Hours (with Justin Bieber)
# 28         29                                           3 Nights
# 29         30                      Hij Is Van Mij (feat. Bizzey)
# ..        ...                                                ...
# 170       171                         Sinterklaas Die Goede Heer
# 171       172                                TikTok (feat. Boef)
# 172       173  Wonderful Christmastime [Edited Version] - Rem...
# 173       174  Zwarte Piet, Wiedewiedewiet (feat. Sinterklaas...
# 174       175                                      Gangster Love
# 175       176                                               24/7
# 176       177  Sinterklaas Goedheiligman (feat. Sinterklaasli...
# 177       178                                            Skyward
# 178       179                                      Feliz Navidad
# 179       180                                        Rain Jacket
# 180       181                                             Sucker
# 181       182                                           Marbella
# 182       183                                  Bidden In De Jeep
# 183       184                                            Shooter
# 184       185                        Always Remember Us This Way
# 185       186                                          #Skakelen
# 186       187                                           It's You
# 187       188                                           Only You
# 188       189                              Holly Jolly Christmas
# 189       190                                 Sirenes/Lange Pijp
# 190       191                                         Hard 2 Get
# 191       192                                          Habri Pia
# 192       193                                      Power Over Me
# 193       194                                  Last Man Standing
# 194       195                                            Parkeer
# 195       196                                            Ewa Ewa
# 196       197                                             Lalala
# 197       198                                             Schuif
# 198       199                                               Wow.
# 199       200                                         Kilometers
#
#                         Artist  Streams  \
# 0                  Tones and I   282587
# 1                Emma Heesters   230923
# 2                     Maroon 5   211134
# 3               Arizona Zervas   199803
# 4                Billie Eilish   171956
# 5                  Post Malone   171042
# 6                       Snelle   163510
# 7                Lewis Capaldi   161499
# 8                     Dua Lipa   156678
# 9                Marco Borsato   143881
# 10                      Regard   143827
# 11               Marco Borsato   137939
# 12                Mariah Carey   132879
# 13                Selena Gomez   117709
# 14                      Snelle   115048
# 15                    Henkie T   113706
# 16              Camila Cabello   110894
# 17               Suzan & Freek   108477
# 18                Shawn Mendes   107923
# 19                  Ed Sheeran   107264
# 20                      MEDUZA   106393
# 21                  Ed Sheeran   105284
# 22                       Wham!   104589
# 23                      Snelle   102558
# 24                   Sam Feldt   101172
# 25                   Sam Smith    98344
# 26                    Bryan Mg    97940
# 27                  Dan + Shay    96316
# 28                Dominic Fike    95275
# 29        Kris Kross Amsterdam    92355
# ..                         ...      ...
# 170  Noord-Hollands Kinderkoor    37999
# 171                   Dopebwoy    37569
# 172             Paul McCartney    37396
# 173              Kinderliedjes    37188
# 174                     JoeyAK    36984
# 175                 Sevn Alias    36784
# 176              Kinderliedjes    36783
# 177            Davina Michelle    36759
# 178             José Feliciano    36391
# 179                 Sevn Alias    36302
# 180             Jonas Brothers    36201
# 181                    LouiVos    36134
# 182                     Frenna    35931
# 183                       Qlas    35852
# 184                  Lady Gaga    35714
# 185              Broederliefde    35490
# 186                  Ali Gatie    35412
# 187                     Frenna    35341
# 188              Michael Bublé    35329
# 195  0hQf7DwPqMBvJIc7rj7iG4         dutch hip hop     58624
# 196  51Fjme0JiitpyXKuyQiCDo               pop rap    114029
# 197  0SEzUzbEk1v6aFsfW73Ojt         dutch hip hop      1104
# 198  7xQAfvXzm3AkraOtGPWIZg               dfw rap  19904838
# 199  2lRp4uhpmkkWZpKHiab1xs         dutch hip hop     43594
#
# [200 rows x 9 columns]

# %% [markdown]
# ## 3. Upsert MongoDB
# If we fetch the data frequently, there are lots of duplicate data entry between each run. The de-duplication happens at insertion. The MongoDB API to use is `collection.replace_one(filter=..., replacement=..., upsert=True)`. The statement matches a document in MongoDB with `filter`, replaces it with `replacement` if the document exists or inserts `replacement` into the database if `filter` matches nothing.

# %%
import pymongo

client = pymongo.MongoClient()

# %%
db = client.get_database("energy")
collection = db.get_collection("energy")
update_count = 0
for record in df.to_dict('records'):
    result = collection.replace_one(
        filter={'Datetime': record['Datetime']},    # locate the document if exists
        replacement=record,                         # latest document
        upsert=True)                                # update if exists, insert if not
    if result.matched_count > 0:
        update_count += 1
print(f"rows={df.shape[0]}, update={update_count}, "
      f"insert={df.shape[0]-update_count}")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-117-b30f6895922d> in <module>
#       6         filter={'Datetime': record['Datetime']},    # locate the document if exists
#       7         replacement=record,                         # latest document
# ----> 8         upsert=True)                                # update if exists, insert if not
#       9     if result.matched_count > 0:
#      10         update_count += 1
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in replace_one(self, filter, replacement, upsert, bypass_document_validation, collation, session)
#     928                 write_concern=write_concern,
#     929                 bypass_doc_val=bypass_document_validation,
# --> 930                 collation=collation, session=session),
#     931             write_concern.acknowledged)
#     932
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     854         return self.__database.client._retryable_write(
#     855             (write_concern or self.write_concern).acknowledged and not multi,
# --> 856             _update, session)
#     857
#     858     def replace_one(self, filter, replacement, upsert=False,
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1489     def _retryable_write(self, retryable, func, session):
#    1490         """Internal retryable write helper."""
# -> 1491         with self._tmp_session(session) as s:
#    1492             return self._retry_with_session(retryable, func, s, None)
#    1493
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1818             return
#    1819
# -> 1820         s = self._ensure_session(session)
#    1821         if s and close:
#    1822             with s:
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1805             # Don't make implicit sessions causally consistent. Applications
#    1806             # should always opt-in.
# -> 1807             return self.__start_session(True, causal_consistency=False)
#    1808         except (ConfigurationError, InvalidOperation):
#    1809             # Sessions not supported, or multiple users authenticated.
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1758
#    1759         # Raises ConfigurationError if sessions are not supported.
# -> 1760         server_session = self._get_server_session()
#    1761         opts = client_session.SessionOptions(**kwargs)
#    1762         return client_session.ClientSession(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1791     def _get_server_session(self):
#    1792         """Internal: start or resume a _ServerSession."""
# -> 1793         return self._topology.get_server_session()
#    1794
#    1795     def _return_server_session(self, server_session, lock):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in get_server_session(self)
#     475                             any_server_selector,
#     476                             self._settings.server_selection_timeout,
# --> 477                             None)
#     478                 elif not self._description.readable_servers:
#     479                     self._select_servers_loop(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     203             if timeout == 0 or now > end_time:
#     204                 raise ServerSelectionTimeoutError(
# --> 205                     self._error_message(selector))
#     206
#     207             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %%
db = client.get_database("spotify")
collection = db.get_collection("spotify")
update_count = 0
for record in df.to_dict('records'):
    result = collection.replace_one(
        filter={'date': record['date']},    # locate the document if exists
        replacement=record,                         # latest document
        upsert=True)                                # update if exists, insert if not
    if result.matched_count > 0:
        update_count += 1
print(f"rows={df.shape[0]}, update={update_count}, "
      f"insert={df.shape[0]-update_count}")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-111-ed10af679019> in <module>
#       6         filter={'date': record['date']},    # locate the document if exists
#       7         replacement=record,                         # latest document
# ----> 8         upsert=True)                                # update if exists, insert if not
#       9     if result.matched_count > 0:
#      10         update_count += 1
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in replace_one(self, filter, replacement, upsert, bypass_document_validation, collation, session)
#     928                 write_concern=write_concern,
#     929                 bypass_doc_val=bypass_document_validation,
# --> 930                 collation=collation, session=session),
#     931             write_concern.acknowledged)
#     932
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     854         return self.__database.client._retryable_write(
#     855             (write_concern or self.write_concern).acknowledged and not multi,
# --> 856             _update, session)
#     857
#     858     def replace_one(self, filter, replacement, upsert=False,
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1489     def _retryable_write(self, retryable, func, session):
#    1490         """Internal retryable write helper."""
# -> 1491         with self._tmp_session(session) as s:
#    1492             return self._retry_with_session(retryable, func, s, None)
#    1493
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1818             return
#    1819
# -> 1820         s = self._ensure_session(session)
#    1821         if s and close:
#    1822             with s:
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1805             # Don't make implicit sessions causally consistent. Applications
#    1806             # should always opt-in.
# -> 1807             return self.__start_session(True, causal_consistency=False)
#    1808         except (ConfigurationError, InvalidOperation):
#    1809             # Sessions not supported, or multiple users authenticated.
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1758
#    1759         # Raises ConfigurationError if sessions are not supported.
# -> 1760         server_session = self._get_server_session()
#    1761         opts = client_session.SessionOptions(**kwargs)
#    1762         return client_session.ClientSession(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1791     def _get_server_session(self):
#    1792         """Internal: start or resume a _ServerSession."""
# -> 1793         return self._topology.get_server_session()
#    1794
#    1795     def _return_server_session(self, server_session, lock):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in get_server_session(self)
#     475                             any_server_selector,
#     476                             self._settings.server_selection_timeout,
# --> 477                             None)
#     478                 elif not self._description.readable_servers:
#     479                     self._select_servers_loop(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     203             if timeout == 0 or now > end_time:
#     204                 raise ServerSelectionTimeoutError(
# --> 205                     self._error_message(selector))
#     206
#     207             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %%
df.to_dict
# Out:
# <bound method DataFrame.to_dict of      Position                                         Track Name  \
# 0           1                                       Dance Monkey
# 1           2                                       Pa Olvidarte
# 2           3                                           Memories
# 3           4                                            ROXANNE
# 4           5                                everything i wanted
# 5           6                                            Circles
# 6           7                                             Reünie
# 7           8                                  Someone You Loved
# 8           9                                    Don't Start Now
# 9          10                                        Lippenstift
# 10         11                                            Ride It
# 11         12                                      Hoe Het Danst
# 12         13                    All I Want for Christmas Is You
# 13         14                                Lose You To Love Me
# 14         15                                        Ze Kent Mij
# 15         16                                            DomDoen
# 16         17                                               Liar
# 17         18                                         Blauwe Dag
# 18         19                                           Señorita
# 19         20                    Beautiful People (feat. Khalid)
# 20         21                                       Lose Control
# 21         22  South of the Border (feat. Camila Cabello & Ca...
# 22         23                                     Last Christmas
# 23         24                                       Voor Je Deur
# 24         25                           Post Malone (feat. RANI)
# 25         26                                  How Do You Sleep?
# 26         27                                            My Bébé
# 27         28                  10,000 Hours (with Justin Bieber)
# 28         29                                           3 Nights
# 29         30                      Hij Is Van Mij (feat. Bizzey)
# ..        ...                                                ...
# 170       171                         Sinterklaas Die Goede Heer
# 171       172                                TikTok (feat. Boef)
# 172       173  Wonderful Christmastime [Edited Version] - Rem...
# 173       174  Zwarte Piet, Wiedewiedewiet (feat. Sinterklaas...
# 174       175                                      Gangster Love
# 175       176                                               24/7
# 176       177  Sinterklaas Goedheiligman (feat. Sinterklaasli...
# 177       178                                            Skyward
# 178       179                                      Feliz Navidad
# 179       180                                        Rain Jacket
# 180       181                                             Sucker
# 181       182                                           Marbella
# 182       183                                  Bidden In De Jeep
# 183       184                                            Shooter
# 184       185                        Always Remember Us This Way
# 185       186                                          #Skakelen
# 186       187                                           It's You
# 187       188                                           Only You
# 188       189                              Holly Jolly Christmas
# 189       190                                 Sirenes/Lange Pijp
# 190       191                                         Hard 2 Get
# 191       192                                          Habri Pia
# 192       193                                      Power Over Me
# 193       194                                  Last Man Standing
# 194       195                                            Parkeer
# 195       196                                            Ewa Ewa
# 196       197                                             Lalala
# 197       198                                             Schuif
# 198       199                                               Wow.
# 199       200                                         Kilometers
#
#                         Artist  Streams  \
# 0                  Tones and I   282587
# 1                Emma Heesters   230923
# 2                     Maroon 5   211134
# 3               Arizona Zervas   199803
# 4                Billie Eilish   171956
# 5                  Post Malone   171042
# 6                       Snelle   163510
# 7                Lewis Capaldi   161499
# 8                     Dua Lipa   156678
# 9                Marco Borsato   143881
# 10                      Regard   143827
# 11               Marco Borsato   137939
# 12                Mariah Carey   132879
# 13                Selena Gomez   117709
# 14                      Snelle   115048
# 15                    Henkie T   113706
# 16              Camila Cabello   110894
# 17               Suzan & Freek   108477
# 18                Shawn Mendes   107923
# 19                  Ed Sheeran   107264
# 20                      MEDUZA   106393
# 21                  Ed Sheeran   105284
# 22                       Wham!   104589
# 23                      Snelle   102558
# 24                   Sam Feldt   101172
# 25                   Sam Smith    98344
# 26                    Bryan Mg    97940
# 27                  Dan + Shay    96316
# 28                Dominic Fike    95275
# 29        Kris Kross Amsterdam    92355
# ..                         ...      ...
# 170  Noord-Hollands Kinderkoor    37999
# 171                   Dopebwoy    37569
# 172             Paul McCartney    37396
# 173              Kinderliedjes    37188
# 174                     JoeyAK    36984
# 175                 Sevn Alias    36784
# 176              Kinderliedjes    36783
# 177            Davina Michelle    36759
# 178             José Feliciano    36391
# 179                 Sevn Alias    36302
# 180             Jonas Brothers    36201
# 181                    LouiVos    36134
# 182                     Frenna    35931
# 183                       Qlas    35852
# 184                  Lady Gaga    35714
# 185              Broederliefde    35490
# 186                  Ali Gatie    35412
# 187                     Frenna    35341
# 188              Michael Bublé    35329
# 189                  Figo Gang    35173
# 190                   Bryan Mg    35091
# 191              Broederliefde    34949
# 192             Dermot Kennedy    34879
# 193                 Yung Felix    34860
# 194                     DJEZJA    34460
# 195                      Chivv    34459
# 196                        Y2K    34454
# 197                      LA$$A    34224
# 198                Post Malone    34165
# 199                      Kevin    34140
#
#                                                    URL       date  \
# 0    https://open.spotify.com/track/1rgnBhdG2JDFTbY... 2019-12-05
# 179  https://open.spotify.com/track/6C5acSXF1GP61KZ... 2019-12-05
# 180  https://open.spotify.com/track/22vgEDb5hykfaTw... 2019-12-05
# 181  https://open.spotify.com/track/5MvAx8zJ16DPQXu... 2019-12-05
# 182  https://open.spotify.com/track/6RKVbvilqMVJxWg... 2019-12-05
# 183  https://open.spotify.com/track/7y2r0n2RRnLhoqS... 2019-12-05
# 184  https://open.spotify.com/track/2rbDhOo9Fh61Bbu... 2019-12-05
# 185  https://open.spotify.com/track/74HB8husrIF08RD... 2019-12-05
# 186  https://open.spotify.com/track/5DqdesEfbRyOlSS... 2019-12-05
# 187  https://open.spotify.com/track/6XhO1FHfsNc3ULW... 2019-12-05
# 188  https://open.spotify.com/track/6tjituizSxwSmBB... 2019-12-05
# 189  https://open.spotify.com/track/0sMDa9Hm2ov1DsR... 2019-12-05
# 190  https://open.spotify.com/track/5aDKZysYr35N9Y0... 2019-12-05
# 191  https://open.spotify.com/track/4MMkBJL9YXYeoEu... 2019-12-05
# 192  https://open.spotify.com/track/4tViDtaHuSLnh7H... 2019-12-05
# 193  https://open.spotify.com/track/7JqF4AHCyokdICr... 2019-12-05
# 194  https://open.spotify.com/track/4VCmGsupHxj3YoK... 2019-12-05
# 195  https://open.spotify.com/track/0hQf7DwPqMBvJIc... 2019-12-05
# 196  https://open.spotify.com/track/51Fjme0JiitpyXK... 2019-12-05
# 197  https://open.spotify.com/track/0SEzUzbEk1v6aFs... 2019-12-05
# 198  https://open.spotify.com/track/7xQAfvXzm3AkraO... 2019-12-05
# 199  https://open.spotify.com/track/2lRp4uhpmkkWZpK... 2019-12-05
#
#                          ID                 genre  follwers
# 0    1rgnBhdG2JDFTbYkYRZAku        australian pop    289858
# 1    1RO8Q3w2Jkir8cvvGEApI0           channel pop     46336
# 2    2b8fOow8UzyDFAE27YhOZM                   pop  21061494
# 3    696DnlkuDOXcMAnKlTgXXK               pop rap    118012
# 4    3ZCTVFBt2Brf31RLEnCkWJ            electropop  16600385
# 5    21jGcNKet2qwijlDFuPiPb               dfw rap  19904838
# 6    5S7YAM3lcfPNBSTVyciwCu         dutch hip hop    126463
# 7    7qEHsqek33rTcFNT9PFqLf                   pop   1711626
# 8    6WrI0LAC5M1Rw2MnX2ZvEg             dance pop  14379060
# 9    3D9MKbMaHCZjSEcCWf4wDm         dutch cabaret    441126
# 10   2tnVG71enUj33Ic2nFN6kZ               pop edm     24333
# 11   5cYOVkA2cnjKid9yigaMwq         dutch cabaret    441126
# 12   0bYg9bo50gSsH3LtXe2SQn             dance pop   5009734
# 13   1HfMVBKM75vxSfsQ5VefZ5             dance pop  18083839
# 14   3BiBIgQFa8K4EOxisyhXX7         dutch hip hop    126463
# 15   5vJpSCkDDqLE6bNF4cRqRG         dutch hip hop     38261
# 16   7LzouaWGFCy4tkXDOOnEyM             dance pop  13324076
# 17   0N1sqwppd1BwhNdjcIDEG2             dutch pop     52431
# 18   6v3KW9xbzN5yKLt9YKDYA2          canadian pop  21920603
